# %%
import random

print("🤖 AI Motivational Quote Generator")
print("Welcome! Get inspired with a random motivational quote.\n")

quotes = [
"Believe in yourself and all that you are.",
"Success is not final, failure is not fatal.",
"Never stop learning.",
"Dream big and dare to fail.",
"Push yourself because no one else will do it for you.",
"Great things take time.",
"Stay positive and work hard.",
"Your only limit is your mind.",
"Every day is a new opportunity.",
"Work hard in silence, let success make the noise."
]

input("Press Enter to generate a motivational quote...")

quote = random.choice(quotes)

print("\n✨ Your Motivational Quote:")
print(quote)

print("\nHave a great day! Keep learning AI and ML 🚀")
# Out:
# 🤖 AI Motivational Quote Generator
# Welcome! Get inspired with a random motivational quote.
#
# Press Enter to generate a motivational quote...
#
# ✨ Your Motivational Quote:
# Dream big and dare to fail.
#
# Have a great day! Keep learning AI and ML 🚀
